# %%
from src import *

env = Environment(WarehouseTypeEnum.Regular,rows = 80, cols = 80)

search1 = Search(AlgorithmTypeEnum.BFS, env)
search2 = Search(AlgorithmTypeEnum.A_STAR, env)

visualize_warehouse(env.map, search1.path)
visualize_warehouse(env.map, search2.path)
# Out:
# Solution found with:  102.0  cost
# Search Time:  0.04599332809448242
# Total Time:  102.04599332809448  with  AlgorithmTypeEnum.BFS
# Solution found with:  97.0  cost
# Search Time:  0.010569095611572266
# Total Time:  97.01056909561157  with  AlgorithmTypeEnum.A_STAR
