# %%
from src import *

env = Environment(WarehouseTypeEnum.Regular,rows = 40, cols = 40)

search1 = Search(AlgorithmTypeEnum.BFS, env)
search2 = Search(AlgorithmTypeEnum.A_STAR, env)

visualize_warehouse(env.map, search1.path)
visualize_warehouse(env.map, search2.path)
# Out:
# Solution found with:  62.0  cost
# Search Time:  0.027991056442260742
# Total Time:  62.02799105644226  with  AlgorithmTypeEnum.BFS
# Solution found with:  56.0  cost
# Search Time:  0.017269134521484375
# Total Time:  56.017269134521484  with  AlgorithmTypeEnum.A_STAR
